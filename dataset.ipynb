# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
node_data = gpd.read_file('./data/[2022-09-05]NODELINKDATA/MOCT_NODE.shp')
link_data = gpd.read_file('./data/[2022-09-05]NODELINKDATA/MOCT_LINK.shp')
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-4-5f1bce504fbc> in <module>
# ----> 1 node_data = gpd.read_file('./data/[2022-09-05]NODELINKDATA/MOCT_NODE.shp')
#       2 link_data = gpd.read_file('./data/[2022-09-05]NODELINKDATA/MOCT_LINK.shp')
#       3
#
# d:\Users\DJK-Office\Anaconda3\envs\pytorch\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# d:\Users\DJK-Office\Anaconda3\envs\pytorch\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     585             row.update(feature["properties"])
#     586             rows.append(row)
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('./data/202010.csv')

# %%
# data = data[data['일자'] == 20201001]

# %%
data['시점명'].value_counts()
# Out:
# 영동대교북단         248
# 올림픽대교남단        186
# 양평역            186
# 질병관리본부         186
# 잠실대교남단         186
#               ...
# 목동9단지           31
# 신정6동주민센터        31
# 성산램프(내부순환로)     31
# 양천문화회관공영주차장     31
# 아카데미하우스         31
# Name: 시점명, Length: 1695, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,8))
plt.plot(np.array(data[data['시점명'] == '영동대교북단'][data['종점명'] == '뚝섬정수장앞'].iloc[:,-24:]).ravel())
# Out:
# d:\Users\DJK-Office\Anaconda3\envs\geopandas\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,8))
plt.plot(np.array(data[data['시점명'] == '영동대교북단'][data['종점명'] == '청담대교북단'].iloc[:,-24:]).ravel())
# Out:
# d:\Users\DJK-Office\Anaconda3\envs\geopandas\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
plt.figure(figsize=(20,8))
plt.plot(np.array(data[data['시점명'] == '영동대교북단'].groupby('일자').mean().iloc[:, -24:]).ravel())

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,8))
plt.plot(np.array(data[data['시점명'] == '영동대교북단'].iloc[:,-24:]).ravel())
# Out:
# d:\Users\DJK-Office\Anaconda3\envs\geopandas\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
data[data['시점명'] == '영동대교북단'].iloc[1, -24:].plot()
# Out:
# <AxesSubplot:>
# d:\Users\DJK-Office\Anaconda3\envs\geopandas\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data[data['시점명'] == '영동대교북단']
# Out:
#             일자 요일   도로명       링크아이디     시점명     종점명    거리  방향    01시    02시  \
# 178   20201001  목  강변북로  1030000400  영동대교북단  뚝섬정수장앞  1457  상행  95.33  99.33
# 225   20201001  목  강변북로  1040000700  영동대교북단  청담대교북단   715  하행  92.25  94.00
# 1400  20201001  목   동일로  1030000200  영동대교북단  영동대교북단   437  상행  38.67  37.67
# 1401  20201001  목   동일로  1040001400  영동대교북단   성수사거리   607  상행  28.04  27.92
# 1477  20201001  목   동일로  1030000100  영동대교북단  영동대교북단   436  하행  53.80  53.76
# 1559  20201001  목   뚝섬로  1040008000  영동대교북단    신양초교   684  상행  22.90  25.89
# 1567  20201001  목   뚝섬로  1030003200  영동대교북단    뚝도시장   584  하행  26.09  27.68
# 3374  20201001  목  영동대로  1220005200  영동대교북단  영동대교남단   859  상행  59.81  59.21
#
#       ...    15시    16시    17시    18시    19시    20시    21시    22시    23시  \
# 178   ...  72.25  74.92  51.08  69.50  75.50  74.92  74.17  75.58  84.42
# 225   ...  48.58  51.08  52.58  53.33  77.08  74.75  73.67  74.25  81.50
# ...

# %%
data[data['종점명'] == '영동대교북단']
# Out:
#             일자 요일   도로명       링크아이디     시점명     종점명    거리  방향    01시    02시  \
# 177   20201001  목  강변북로  1040000800  청담대교북단  영동대교북단   709  상행  92.00  92.42
# 224   20201001  목  강변북로  1030000300  뚝섬정수장앞  영동대교북단  1455  하행  92.25  94.00
# 1400  20201001  목   동일로  1030000200  영동대교북단  영동대교북단   437  상행  38.67  37.67
# 1476  20201001  목   동일로  1040001300   성수사거리  영동대교북단   607  하행  33.37  34.09
# 1477  20201001  목   동일로  1030000100  영동대교북단  영동대교북단   436  하행  53.80  53.76
# 1558  20201001  목   뚝섬로  1030003100    뚝도시장  영동대교북단   584  상행  26.65  27.49
# 1566  20201001  목   뚝섬로  1040008100    신양초교  영동대교북단   684  하행  22.25  24.26
# 3397  20201001  목  영동대로  1220005300  영동대교남단  영동대교북단   859  하행  57.09  58.25
#
#       ...    15시    16시    17시    18시    19시    20시    21시    22시    23시  \
# 177   ...  69.67  66.42  57.33  63.58  69.17  69.58  71.25  73.25  81.92
# 224   ...  48.58  51.08  52.58  53.33  77.08  74.75  73.67  74.25  81.50
# ...
